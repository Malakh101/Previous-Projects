# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv('Africa Food production (1).csv')
df
# Out:
#         Country                Item  Year  Value
# 0       Algeria  Wheat and products  2004   2731
# 1       Algeria  Wheat and products  2005   2415
# 2       Algeria  Wheat and products  2006   2688
# 3       Algeria  Wheat and products  2007   2319
# 4       Algeria  Wheat and products  2008   1111
# ...         ...                 ...   ...    ...
# 23105  Zimbabwe         Crustaceans  2009      0
# 23106  Zimbabwe         Crustaceans  2010      0
# 23107  Zimbabwe         Crustaceans  2011      0
# 23108  Zimbabwe         Crustaceans  2012      0
# 23109  Zimbabwe         Crustaceans  2013      0
#
# [23110 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23110 entries, 0 to 23109
# Data columns (total 4 columns):
# Country    23110 non-null object
# Item       23110 non-null object
# Year       23110 non-null int64
# Value      23110 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 722.3+ KB

# %%
df.Year=pd.to_datetime(df.Year,format='%Y')

df
# Out:
#         Country                Item       Year  Value
# 0       Algeria  Wheat and products 2004-01-01   2731
# 1       Algeria  Wheat and products 2005-01-01   2415
# 2       Algeria  Wheat and products 2006-01-01   2688
# 3       Algeria  Wheat and products 2007-01-01   2319
# 4       Algeria  Wheat and products 2008-01-01   1111
# ...         ...                 ...        ...    ...
# 23105  Zimbabwe         Crustaceans 2009-01-01      0
# 23106  Zimbabwe         Crustaceans 2010-01-01      0
# 23107  Zimbabwe         Crustaceans 2011-01-01      0
# 23108  Zimbabwe         Crustaceans 2012-01-01      0
# 23109  Zimbabwe         Crustaceans 2013-01-01      0
#
# [23110 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23110 entries, 0 to 23109
# Data columns (total 4 columns):
# Country    23110 non-null object
# Item       23110 non-null object
# Year       23110 non-null datetime64[ns]
# Value      23110 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 722.3+ KB

# %%
df.groupby('Year').describe()
# Out:
#              Value
#              count        mean          std  min  25%   50%     75%      max
# Year
# 2004-01-01  2312.0  286.767301  1436.289792  0.0  2.0  16.0   90.00  38845.0
# 2005-01-01  2312.0  298.986592  1519.257333  0.0  3.0  16.0   98.00  41565.0
# 2006-01-01  2312.0  310.814014  1600.528959  0.0  3.0  17.0   98.00  45721.0
# 2007-01-01  2312.0  305.215830  1513.409490  0.0  3.0  17.0  102.00  43410.0
# 2008-01-01  2312.0  318.686851  1585.354394  0.0  3.0  18.0  107.00  44582.0
# 2009-01-01  2312.0  323.040657  1443.760812  0.0  3.0  18.0  110.00  36822.0
# 2010-01-01  2312.0  340.166955  1570.898897  0.0  3.0  20.0  113.00  42533.0
# 2011-01-01  2312.0  351.303633  1729.856070  0.0  3.0  21.0  119.25  52403.0
# 2012-01-01  2307.0  364.831816  1792.138471  0.0  3.0  21.0  122.00  54000.0
# 2013-01-01  2307.0  378.227568  1834.925452  0.0  3.0  22.0  125.00  53000.0

# %%
df.groupby('Year').mean().plot.line(figsize=(5,3))

# %%
df.groupby('Item').mean().plot.bar(figsize=(15,7))

# %%
df.groupby('Country').describe()
# Out:
#                              Value                                        \
#                              count         mean          std  min    25%
# Country
# Algeria                      580.0   325.258621   746.119621  0.0   1.00
# Angola                       540.0   362.035185  1603.100582  0.0   4.00
# Benin                        590.0   149.274576   535.228615  0.0   4.00
# Botswana                     340.0    14.141176    26.206871  0.0   0.00
# Burkina Faso                 430.0   232.858140   550.321606  0.0   7.25
# Cabo Verde                   330.0     5.024242     6.994093  0.0   0.00
# Cameroon                     650.0   304.107692   628.245740  0.0   7.00
# Central African Republic     450.0    55.380000   109.224723  0.0   4.25
# Chad                         390.0   115.584615   167.871085  0.0  17.25
# Congo                        500.0    51.582000   178.518944  0.0   2.00
# Cote d'Ivoire                640.0   285.134375   788.336974  0.0   7.00
# ...

# %%
sns.heatmap(somn.corr())

# %%
df.groupby('Country').mean().plot.bar(figsize=(15,5))
plt.savefig('Output.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# # some of the top producing food countries are not the top food suppliers which can explain why the food shortage problem keeps persisiting. Though it is increasing gradually as at 2010. so basically the demand of food is not being met, countries that produce more food should be encouraged to supply more

# %% [markdown]
# # Food supply analysis

# %%
#x=df['Year']
#y=df['Item']
#plt.plot(x,y)
#x

# %%
df2= pd.read_csv('Africa Food supply(1).csv')
df2
# Out:
#       Country  Year  Value
# 0     Algeria  2004   2987
# 1     Algeria  2005   2958
# 2     Algeria  2006   3047
# 3     Algeria  2007   3041
# 4     Algeria  2008   3048
# ..        ...   ...    ...
# 445  Zimbabwe  2009   2147
# 446  Zimbabwe  2010   2168
# 447  Zimbabwe  2011   2200
# 448  Zimbabwe  2012   2197
# 449  Zimbabwe  2013   2110
#
# [450 rows x 3 columns]

# %%
df2.Year=pd.to_datetime(df2.Year,format='%Y')

df2
# Out:
#       Country       Year  Value
# 0     Algeria 2004-01-01   2987
# 1     Algeria 2005-01-01   2958
# 2     Algeria 2006-01-01   3047
# 3     Algeria 2007-01-01   3041
# 4     Algeria 2008-01-01   3048
# ..        ...        ...    ...
# 445  Zimbabwe 2009-01-01   2147
# 446  Zimbabwe 2010-01-01   2168
# 447  Zimbabwe 2011-01-01   2200
# 448  Zimbabwe 2012-01-01   2197
# 449  Zimbabwe 2013-01-01   2110
#
# [450 rows x 3 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 3 columns):
# Country    450 non-null object
# Year       450 non-null datetime64[ns]
# Value      450 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 10.7+ KB

# %%
df2.groupby('Country').describe()
# Out:
#                             Value                                       \
#                             count    mean         std     min      25%
# Country
# Algeria                      10.0  3111.8  117.420233  2958.0  3042.50
# Angola                       10.0  2255.6  151.032888  2030.0  2132.50
# Benin                        10.0  2537.8   67.994771  2435.0  2476.00
# Botswana                     10.0  2226.3   66.337605  2150.0  2185.75
# Burkina Faso                 10.0  2607.2   88.219172  2463.0  2549.25
# Cabo Verde                   10.0  2551.4   33.200402  2513.0  2523.25
# Cameroon                     10.0  2460.3  138.728392  2246.0  2360.00
# Central African Republic     10.0  2071.9   90.529860  1879.0  2026.75
# Chad                         10.0  2051.1   37.604521  2021.0  2026.25
# Congo                        10.0  2153.0   58.469365  2043.0  2136.75
# Cote d'Ivoire                10.0  2766.6   27.661445  2727.0  2738.25
# ...

# %%
df2.groupby('Country').mean().plot.bar(figsize=(15,5))

# %%
df2.groupby('Year').describe()
# Out:
#            Value                                                           \
#            count         mean         std     min     25%     50%     75%
# Year
# 2004-01-01  45.0  2394.222222  374.504272  1866.0  2092.0  2271.0  2541.0
# 2005-01-01  45.0  2409.288889  364.728767  1873.0  2134.0  2311.0  2583.0
# 2006-01-01  45.0  2430.800000  371.260849  1838.0  2143.0  2325.0  2603.0
# 2007-01-01  45.0  2447.755556  374.898481  1781.0  2166.0  2344.0  2711.0
# 2008-01-01  45.0  2460.755556  378.895114  1801.0  2164.0  2439.0  2653.0
# 2009-01-01  45.0  2482.222222  380.775160  1878.0  2194.0  2435.0  2683.0
# 2010-01-01  45.0  2497.400000  385.757307  1904.0  2198.0  2370.0  2706.0
# 2011-01-01  45.0  2515.422222  383.728508  1907.0  2213.0  2407.0  2706.0
# 2012-01-01  45.0  2527.644444  388.466926  1923.0  2200.0  2414.0  2707.0
# 2013-01-01  45.0  2532.244444  396.861274  1879.0  2208.0  2456.0  2720.0
#
#
#                max
# Year
# 2004-01-01  3309.0
# 2005-01-01  3367.0
# ...

# %%
plot_year =df2.groupby('Year').mean().plot.line(figsize=(12,5),c='r')
